# %%
import pandas as pd
df = pd.read_parquet("test.parquet")
print(df.head())
# Out:
#             MDDate     MDTime  SecurityType SecuritySubType SecurityID  \
# 11126863  20250120  145915000             2           02001     002144
# 11126864  20250120  145915000             2           02001     002265
# 11126865  20250120  145915000             2           02001     002120
# 11126866  20250120  145915000             2           02001     002199
# 11126867  20250120  145915000             2           02001     002212
#
#           SecurityIDSource Symbol TradingPhaseCode  PreClosePx  NumTrades  \
# 11126863               102   宏达高科                5       10.19       7014
# 11126864               102   建设工业                5       28.95     176843
# 11126865               102   韵达股份                5        7.50      19183
# 11126866               102   东晶电子                5        7.66       5223
# 11126867               102    天融信                5        6.83      48132
#
#           ...  Sell9NumOrders  Buy10Price  Buy10OrderQty  Buy10NumOrders  \
# ...

# %%
df["MDTime"].unique()
# Out:
# array(['145915000', '145857000', '145848000', '145906000', '145821000',
#        '145839000', '145842000', '145824000', '145812000', '145830000',
#        '145924000', '145833000', '145851000', '145745000', '145754000',
#        '145930000', '145836000', '145933000', '145845000', '145942000',
#        '145918000', '145803000', '145936000', '145948000', '145854000',
#        '145951000', '145912000', '145909000', '145954000', '145945000',
#        '145939000', '145957000', '150000000', '150100000', '150103000',
#        '150106000', '150109000', '150112000', '150115000', '150118000',
#        '150121000', '150124000', '150127000', '150130000', '150133000',
#        '150136000', '150139000', '150142000', '150145000', '150148000',
#        '150151000', '150154000', '150157000', '150200000', '150203000',
#        '150206000', '150209000', '150212000', '150215000', '150218000',
#        '150221000', '150224000', '150227000', '150230000', '150233000',
# ...

# %%
df["Symbol"].unique()[:100]
# Out:
# array(['宏达高科', '建设工业', '韵达股份', '东晶电子', '天融信', '延华智能', '远 望 谷', '海陆重工',
#        '紫光国微', '海翔药业', '招商公路', '广电运通', '塔牌集团', '宁波银行', '康强电子', '东华软件',
#        '拓维信息', '红 宝 丽', '新里程', '海 利 得', '广百股份', '三特索道', '东方海洋', '海亮股份',
#        '天康生物', '西部材料', '南极电商', '石基信息', '楚江新材', '华明装备', '世荣兆业', '全 聚 德',
#        '合兴包装', '金风科技', '武汉凡谷', '岩山科技', '生 意 宝', '亿帆医药', 'ST易购', '广博股份',
#        '湘潭电化', '游族网络', '沃尔核材', '国光电器', '保龄宝', '江特电机', '三变科技', 'ST天邦',
#        '科陆电子', '永新股份', '聚力文化', '宁波华翔', '友阿股份', '中核钛白', '宝武镁业', '航天电器',
#        '嘉应制药', '电投能源', '奥 特 迅', '准油股份', 'ST交投', '安妮股份', '芭田股份', '梦网科技',
#        '云南能投', '美年健康', '川润股份', '水晶光电', '科大讯飞', '大立科技', '通润装备', '太阳纸业',
#        '顺络电子', '国统股份', '川大智胜', '盾安环境', '利欧股份', '东方雨虹', '达 意 隆', '鸿博股份',
#        '大华股份', '泰和新材', '孚日股份', '莱茵生物', '正威新材', '大为股份', '威尔泰', '招商港口',
#        '九阳股份', '莱宝高科', '纳思达', '海南发展', '大连重工', '飞马国际', '汉钟精机', '方正电机',
#        '福晶科技', '银轮股份', '华帝股份', '东方智造'], dtype=object)

# %%
df["SecuritySubType"].unique()
# Out:
# array(['02001', '02003', '02004'], dtype=object)

# %%
len(df["Buy10OrderQty"].unique())
# Out:
# 814
